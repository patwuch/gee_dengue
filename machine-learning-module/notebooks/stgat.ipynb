# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import os
import torch 
import torch.nn as nn

# %%
df = pd.read_csv(os.path.join('..', 'data', 'processed', 'SEA_dengue_env_monthly_2011-2018.csv'))

# %%
print(df.shape)
df.columns
# Out:
# (15840, 48)
# Index(['admin', 'name', 'Date', 'precipitation_sum', 'temperature_2m_mean',
#        'temperature_2m_sum', 'temperature_2m_min_mean',
#        'temperature_2m_min_sum', 'temperature_2m_max_mean',
#        'temperature_2m_max_sum', 'total_precipitation_sum_mean',
#        'total_precipitation_sum_sum', 'total_evaporation_sum_mean',
#        'total_evaporation_sum_sum', 'potential_evaporation_sum_mean',
#        'potential_evaporation_sum_sum', 'evaporation_from_bare_soil_sum_mean',
#        'evaporation_from_bare_soil_sum_sum',
#        'evaporation_from_open_water_surfaces_excluding_oceans_sum_mean',
#        'evaporation_from_open_water_surfaces_excluding_oceans_sum_sum',
#        'evaporation_from_the_top_of_canopy_sum_mean',
#        'evaporation_from_the_top_of_canopy_sum_sum',
#        'evaporation_from_vegetation_transpiration_sum_mean',
#        'evaporation_from_vegetation_transpiration_sum_sum', 'LST_Day_1km_mean',
#        'LST_Night_1km_mean', 'NDVI_mean', 'EVI_mean', 'LC_Type1_pct_class1',
#        'LC_Type1_pct_class2', 'LC_Type1_pct_class3', 'LC_Type1_pct_class4',
#        'LC_Type1_pct_class5', 'LC_Type1_pct_class6', 'LC_Type1_pct_class7',
#        'LC_Type1_pct_class8', 'LC_Type1_pct_class9', 'LC_Type1_pct_class10',
#        'LC_Type1_pct_class11', 'LC_Type1_pct_class12', 'LC_Type1_pct_class13',
#        'LC_Type1_pct_class14', 'LC_Type1_pct_class15', 'LC_Type1_pct_class16',
#        'LC_Type1_pct_class17', 'population_sum', 'dengue_total', 'IR'],
#       dtype='str')

# %%
for col in df.columns:
    print(f"{col}: {df[col].isna().sum()}")
# Out:
# admin: 0
# name: 0
# Date: 0
# precipitation_sum: 0
# temperature_2m_mean: 96
# temperature_2m_sum: 0
# temperature_2m_min_mean: 96
# temperature_2m_min_sum: 0
# temperature_2m_max_mean: 96
# temperature_2m_max_sum: 0
# total_precipitation_sum_mean: 96
# total_precipitation_sum_sum: 0
# total_evaporation_sum_mean: 96
# total_evaporation_sum_sum: 0
# potential_evaporation_sum_mean: 96
# potential_evaporation_sum_sum: 0
# evaporation_from_bare_soil_sum_mean: 96
# evaporation_from_bare_soil_sum_sum: 0
# evaporation_from_open_water_surfaces_excluding_oceans_sum_mean: 96
# evaporation_from_open_water_surfaces_excluding_oceans_sum_sum: 0
# evaporation_from_the_top_of_canopy_sum_mean: 96
# evaporation_from_the_top_of_canopy_sum_sum: 0
# evaporation_from_vegetation_transpiration_sum_mean: 96
# evaporation_from_vegetation_transpiration_sum_sum: 0
# LST_Day_1km_mean: 5
# LST_Night_1km_mean: 453
# NDVI_mean: 7
# EVI_mean: 7
# LC_Type1_pct_class1: 0
# LC_Type1_pct_class2: 0
# LC_Type1_pct_class3: 0
# LC_Type1_pct_class4: 0
# LC_Type1_pct_class5: 0
# LC_Type1_pct_class6: 0
# LC_Type1_pct_class7: 0
# LC_Type1_pct_class8: 0
# LC_Type1_pct_class9: 0
# LC_Type1_pct_class10: 0
# LC_Type1_pct_class11: 0
# LC_Type1_pct_class12: 0
# LC_Type1_pct_class13: 0
# LC_Type1_pct_class14: 0
# LC_Type1_pct_class15: 0
# LC_Type1_pct_class16: 0
# LC_Type1_pct_class17: 0
# population_sum: 0
# dengue_total: 3155
# IR: 3155

# %%
fig, ax = plt.subplots()

ax.hist(x, bins=8, linewidth=0.5, edgecolor="white")

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 56), yticks=np.linspace(0, 56, 9))

plt.show()

# %%
df
# Out:
#                    admin      name        Date  precipitation_sum  \
# 0      Brunei Darussalam    Belait  2011-01-01        1821.732979
# 1      Brunei Darussalam    Belait  2011-02-01        1585.472964
# 2      Brunei Darussalam    Belait  2011-03-01        1367.200440
# 3      Brunei Darussalam    Belait  2011-04-01        1251.725802
# 4      Brunei Darussalam    Belait  2011-05-01        1018.664012
# ...                  ...       ...         ...                ...
# 15835           Viet Nam  Viet Nam  2018-08-01      124509.901467
# 15836           Viet Nam  Viet Nam  2018-09-01      101516.512105
# 15837           Viet Nam  Viet Nam  2018-10-01       58473.027215
# 15838           Viet Nam  Viet Nam  2018-11-01       36717.538036
# 15839           Viet Nam  Viet Nam  2018-12-01       29124.475371
#
#        temperature_2m_mean  temperature_2m_sum  temperature_2m_min_mean  \
# 0                24.800001          679.617277                22.554097
# 1                24.733739          677.801439                22.505614
# 2                25.096626          687.745958                22.727503
# 3                25.487851          698.467063                23.134311
# 4                26.440004          724.559782                23.723969
# ...                    ...                 ...                      ...
# 15835            25.327574        69005.323564                23.125153
# 15836            24.810565        67596.725354                22.222048
# 15837            23.336573        63580.814732                20.564712
# 15838            22.272857        60682.705736                19.206265
# 15839            20.274506        55238.170799                17.636572
#
#        temperature_2m_min_sum  temperature_2m_max_mean  \
# 0                  618.070713                28.797685
# 1                  616.742092                28.609136
# 2                  622.822705                29.313795
# 3                  633.970850                29.471163
# 4                  650.129777                30.342112
# ...                       ...                      ...
# 15835            63004.797805                28.735879
# 15836            60544.274064                28.430696
# 15837            56028.841063                26.869188
# 15838            52327.732963                25.981823
# 15839            48051.083819                23.527817
#
#        temperature_2m_max_sum  ...  LC_Type1_pct_class11  \
# 0                  789.169512  ...              0.003496
# 1                  784.002522  ...              0.003496
# 2                  803.312931  ...              0.003496
# 3                  807.625448  ...              0.003496
# 4                  831.492862  ...              0.003496
# ...                       ...  ...                   ...
# 15835            78291.295952  ...              0.037537
# 15836            77459.821351  ...              0.037537
# 15837            73205.470271  ...              0.037537
# 15838            70787.833260  ...              0.037537
# 15839            64101.860026  ...              0.037537
#
#        LC_Type1_pct_class12  LC_Type1_pct_class13  LC_Type1_pct_class14  \
# 0                  0.000000              0.011069               0.00000
# 1                  0.000000              0.011069               0.00000
# 2                  0.000000              0.011069               0.00000
# 3                  0.000000              0.011069               0.00000
# 4                  0.000000              0.011069               0.00000
# ...                     ...                   ...                   ...
# 15835              0.127768              0.016299               0.07715
# 15836              0.127768              0.016299               0.07715
# 15837              0.127768              0.016299               0.07715
# 15838              0.127768              0.016299               0.07715
# 15839              0.127768              0.016299               0.07715
#
#        LC_Type1_pct_class15  LC_Type1_pct_class16  LC_Type1_pct_class17  \
# 0              0.000000e+00               0.00000              0.003579
# 1              0.000000e+00               0.00000              0.003579
# 2              0.000000e+00               0.00000              0.003579
# 3              0.000000e+00               0.00000              0.003579
# 4              0.000000e+00               0.00000              0.003579
# ...                     ...                   ...                   ...
# 15835          5.364803e-07               0.00166              0.026380
# 15836          5.364803e-07               0.00166              0.026380
# 15837          5.364803e-07               0.00166              0.026380
# 15838          5.364803e-07               0.00166              0.026380
# 15839          5.364803e-07               0.00166              0.026380
#
#        population_sum  dengue_total         IR
# 0        5.541631e+04           NaN        NaN
# 1        5.541631e+04           NaN        NaN
# 2        5.541631e+04           NaN        NaN
# 3        5.541631e+04           NaN        NaN
# 4        5.541631e+04           NaN        NaN
# ...               ...           ...        ...
# 15835    8.229152e+07       10285.0  12.498249
# 15836    8.229152e+07       15964.0  19.399325
# 15837    8.229152e+07       17439.0  21.191733
# 15838    8.229152e+07       19962.0  24.257662
# 15839    8.229152e+07       24533.0  29.812305
#
# [15840 rows x 48 columns]
